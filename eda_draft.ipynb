# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, StandardScaler

# %%
input_path = 'C:\\Users\\Jackie\\Desktop\\20181025_PredictDiseaseSpread\\Data\\'

# %%
raw_df = pd.read_csv(input_path + 'dengue_features_train.csv')
raw_df.fillna(0, inplace=True)
raw_label = pd.read_csv(input_path + 'dengue_labels_train.csv')
X, X_test, y, y_test = train_test_split(raw_df, raw_label, test_size=0.2, random_state=18)

# %%
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.25, random_state=18)

# %%
X_train.head()
# Out:
#      city  year  weekofyear week_start_date   ndvi_ne   ndvi_nw   ndvi_se  \
# 1414   iq  2009          37      2009-09-10  0.189617  0.192000  0.236814
# 623    sj  2002          17      2002-04-23 -0.017600  0.051900  0.113571
# 1180   iq  2005          10      2005-03-12  0.155843  0.137083  0.241871
# 587    sj  2001          33      2001-08-13  0.089850  0.127833  0.200814
# 1286   iq  2007          13      2007-03-26  0.238671  0.244743  0.216229
#
#        ndvi_sw  precipitation_amt_mm  reanalysis_air_temp_k  \
# 1414  0.269686                 13.74             299.855714
# 623   0.111629                214.76             297.970000
# 1180  0.146429                155.54             297.957143
# 587   0.205114                 29.00             300.742857
# 1286  0.259186                 93.14             297.835714
#
#             ...          reanalysis_precip_amt_kg_per_m2  \
# 1414        ...                                     9.30
# 623         ...                                    31.00
# 1180        ...                                   201.40
# 587         ...                                    50.46
# 1286        ...                                    58.40
#
#       reanalysis_relative_humidity_percent  reanalysis_sat_precip_amt_mm  \
# 1414                             75.232857                         13.74
# 623                              83.657143                        214.76
# 1180                             97.687143                        155.54
# 587                              82.087143                         29.00
# 1286                             93.585714                         93.14
#
#       reanalysis_specific_humidity_g_per_kg  reanalysis_tdtr_k  \
# 1414                              15.865714          13.042857
# 623                               16.368571           2.514286
# 1180                              19.274286           4.828571
# 587                               18.892857           2.600000
# 1286                              18.214286           8.242857
#
#       station_avg_temp_c  station_diur_temp_rng_c  station_max_temp_c  \
# 1414           29.166667                14.133333                37.4
# 623            25.700000                 6.185714                30.6
# 1180           26.800000                 6.700000                34.8
# 587            28.642857                 5.585714                32.2
# 1286           28.250000                 9.600000                34.6
#
#       station_min_temp_c  station_precip_mm
# 1414                21.4                6.1
# 623                 21.7               69.7
# 1180                23.4                8.6
# 587                 25.6               24.3
# 1286                21.5               66.1
#
# [5 rows x 24 columns]

# %%
y_train.head()
# Out:
#      city  year  weekofyear  total_cases
# 1414   iq  2009          37            2
# 623    sj  2002          17            1
# 1180   iq  2005          10           14
# 587    sj  2001          33           38
# 1286   iq  2007          13            6

# %%
raw_df.isnull().sum()
# Out:
# city                                     0
# year                                     0
# weekofyear                               0
# week_start_date                          0
# ndvi_ne                                  0
# ndvi_nw                                  0
# ndvi_se                                  0
# ndvi_sw                                  0
# precipitation_amt_mm                     0
# reanalysis_air_temp_k                    0
# reanalysis_avg_temp_k                    0
# reanalysis_dew_point_temp_k              0
# reanalysis_max_air_temp_k                0
# reanalysis_min_air_temp_k                0
# reanalysis_precip_amt_kg_per_m2          0
# reanalysis_relative_humidity_percent     0
# reanalysis_sat_precip_amt_mm             0
# reanalysis_specific_humidity_g_per_kg    0
# reanalysis_tdtr_k                        0
# station_avg_temp_c                       0
# station_diur_temp_rng_c                  0
# station_max_temp_c                       0
# station_min_temp_c                       0
# station_precip_mm                        0
# dtype: int64

# %%
# Encoding categorical data
# Encoding the Independent Variable
labelencoder_X = LabelEncoder()
X_val[:, 0] = labelencoder_X.fit_transform(X_val[:, 0])
onehotencoder = OneHotEncoder(categorical_features = [0])
X_val = onehotencoder.fit_transform(X_val).toarray()
# Encoding the Dependent Variable
labelencoder_y = LabelEncoder()
y_val = labelencoder_y.fit_transform(y_val)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-74f195a26a96> in <module>()
#       2 # Encoding the Independent Variable
#       3 labelencoder_X = LabelEncoder()
# ----> 4 X_val[:, 0] = labelencoder_X.fit_transform(X_val[:, 0])
#       5 onehotencoder = OneHotEncoder(categorical_features = [0])
#       6 X_val = onehotencoder.fit_transform(X_val).toarray()
#
# D:\Programs\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# D:\Programs\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# D:\Programs\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    2485         """Return the cached item, item represents a label indexer."""
#    2486         cache = self._item_cache
# -> 2487         res = cache.get(item)
#    2488         if res is None:
#    2489             values = self._data.get(item)
#
# TypeError: unhashable type: 'slice'

# %%
# Feature Scaling
sc_X = StandardScaler()
X_train = sc_X.fit_transform(X_train)
X_test = sc_X.transform(X_test)
sc_y = StandardScaler()
y_train = sc_y.fit_transform(y_train)

# %%
# Fitting Logistic Regression to the Training set
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(random_state = 0)
classifier.fit(X_train, y_train)

# Predicting the Test set results
y_pred = classifier.predict(X_test)
# Out:
# array([ 5.69996837e+00, -5.69996837e+00,  4.51685037e+01,  6.28916427e-01,
#        -4.70231291e-03,  1.98272871e+00, -9.86194275e+00, -1.12112636e+02,
#        -1.97146818e+01, -2.03329947e-02,  3.17822481e+00, -5.69265049e+00,
#         2.46070440e+00,  1.50333478e+00, -1.18446745e+00, -1.40663055e-02,
#        -1.35764169e+00, -2.03329947e-02,  6.21404159e+00, -2.59979008e+00,
#        -6.31278671e-01,  3.96333429e-01, -1.40003246e-01, -2.79680899e-01,
#         1.23625574e-02])

# %%
# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1019 entries, 177 to 1322
# Data columns (total 25 columns):
# iq                                       1019 non-null int32
# sj                                       1019 non-null int32
# year                                     1019 non-null int64
# weekofyear                               1019 non-null int64
# date                                     1019 non-null int32
# ndvi_ne                                  1019 non-null float64
# ndvi_nw                                  1019 non-null float64
# ndvi_se                                  1019 non-null float64
# ndvi_sw                                  1019 non-null float64
# precipitation_amt_mm                     1019 non-null float64
# reanalysis_air_temp_k                    1019 non-null float64
# reanalysis_avg_temp_k                    1019 non-null float64
# reanalysis_dew_point_temp_k              1019 non-null float64
# reanalysis_max_air_temp_k                1019 non-null float64
# reanalysis_min_air_temp_k                1019 non-null float64
# reanalysis_precip_amt_kg_per_m2          1019 non-null float64
# reanalysis_relative_humidity_percent     1019 non-null float64
# reanalysis_sat_precip_amt_mm             1019 non-null float64
# reanalysis_specific_humidity_g_per_kg    1019 non-null float64
# reanalysis_tdtr_k                        1019 non-null float64
# station_avg_temp_c                       1019 non-null float64
# station_diur_temp_rng_c                  1019 non-null float64
# station_max_temp_c                       1019 non-null float64
# station_min_temp_c                       1019 non-null float64
# station_precip_mm                        1019 non-null float64
# dtypes: float64(20), int32(3), int64(2)
# memory usage: 195.0 KB

# %%
# Visualising the Training set results
from matplotlib.colors import ListedColormap
X_set, y_set = X_train, y_train
X1, X2 = np.meshgrid(np.arange(start = X_set[:, 0].min() - 1, stop = X_set[:, 0].max() + 1, step = 0.01),
                     np.arange(start = X_set[:, 1].min() - 1, stop = X_set[:, 1].max() + 1, step = 0.01))
plt.contourf(X1, X2, classifier.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape),
             alpha = 0.75, cmap = ListedColormap(('red', 'green')))
plt.xlim(X1.min(), X1.max())
plt.ylim(X2.min(), X2.max())
for i, j in enumerate(np.unique(y_set)):
    plt.scatter(X_set[y_set == j, 0], X_set[y_set == j, 1],
                c = ListedColormap(('red', 'green'))(i), label = j)
plt.title('Logistic Regression (Training set)')
plt.xlabel('Age')
plt.ylabel('Estimated Salary')
plt.legend()
plt.show()
# Out:
# count    1456.000000
# mean       24.675137
# std        43.596000
# min         0.000000
# 25%         5.000000
# 50%        12.000000
# 75%        28.000000
# max       461.000000
# Name: total_cases, dtype: float64

# %%
# Visualising the Test set results
from matplotlib.colors import ListedColormap
X_set, y_set = X_test, y_test
X1, X2 = np.meshgrid(np.arange(start = X_set[:, 0].min() - 1, stop = X_set[:, 0].max() + 1, step = 0.01),
                     np.arange(start = X_set[:, 1].min() - 1, stop = X_set[:, 1].max() + 1, step = 0.01))
plt.contourf(X1, X2, classifier.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape),
             alpha = 0.75, cmap = ListedColormap(('red', 'green')))
plt.xlim(X1.min(), X1.max())
plt.ylim(X2.min(), X2.max())
for i, j in enumerate(np.unique(y_set)):
    plt.scatter(X_set[y_set == j, 0], X_set[y_set == j, 1],
                c = ListedColormap(('red', 'green'))(i), label = j)
plt.title('Logistic Regression (Test set)')
plt.xlabel('Age')
plt.ylabel('Estimated Salary')
plt.legend()
plt.show()

# %%
# Out:
#   city  year  weekofyear  total_cases
# 0   sj  1990          18            4
# 1   sj  1990          19            5
# 2   sj  1990          20            4
# 3   sj  1990          21            3
# 4   sj  1990          22            6

# %%
# Out:
#                 city  year  weekofyear  ndvi_ne   ndvi_nw   ndvi_se   ndvi_sw  \
# week_start_date
# 1990-04-30        sj  1990          18  0.12260  0.103725  0.198483  0.177617
# 1990-05-07        sj  1990          19  0.16990  0.142175  0.162357  0.155486
# 1990-05-14        sj  1990          20  0.03225  0.172967  0.157200  0.170843
#
#                  precipitation_amt_mm  reanalysis_air_temp_k  \
# week_start_date
# 1990-04-30                      12.42             297.572857
# 1990-05-07                      22.82             298.211429
# 1990-05-14                      34.54             298.781429
#
#                  reanalysis_avg_temp_k        ...          \
# week_start_date                               ...
# 1990-04-30                  297.742857        ...
# 1990-05-07                  298.442857        ...
# 1990-05-14                  298.878571        ...
#
#                  reanalysis_precip_amt_kg_per_m2  \
# week_start_date
# 1990-04-30                                 32.00
# 1990-05-07                                 17.94
# 1990-05-14                                 26.10
#
#                  reanalysis_relative_humidity_percent  \
# week_start_date
# 1990-04-30                                  73.365714
# 1990-05-07                                  77.368571
# 1990-05-14                                  82.052857
#
#                  reanalysis_sat_precip_amt_mm  \
# week_start_date
# 1990-04-30                              12.42
# 1990-05-07                              22.82
# 1990-05-14                              34.54
#
#                  reanalysis_specific_humidity_g_per_kg  reanalysis_tdtr_k  \
# week_start_date
# 1990-04-30                                   14.012857           2.628571
# 1990-05-07                                   15.372857           2.371429
# 1990-05-14                                   16.848571           2.300000
#
#                  station_avg_temp_c  station_diur_temp_rng_c  \
# week_start_date
# 1990-04-30                25.442857                 6.900000
# 1990-05-07                26.714286                 6.371429
# 1990-05-14                26.714286                 6.485714
#
#                  station_max_temp_c  station_min_temp_c  station_precip_mm
# week_start_date
# 1990-04-30                     29.4                20.0               16.0
# 1990-05-07                     31.7                22.2                8.6
# 1990-05-14                     32.2                22.8               41.4
#
# [3 rows x 23 columns]
